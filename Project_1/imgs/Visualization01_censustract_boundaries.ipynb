# %%
import simplejson as json
import numpy as np
import matplotlib.pyplot as plt
import utm

bx = open("NYC_2010_Census_Tracts.geojson")
bx = json.loads(bx.read())

polygons = bx['features']

censusTracts = [np.array(bx['features'][k]['geometry']['coordinates'][0][0]) 
                        for k in range(len(bx['features']))]

#censusTracts = utm.from_latlon(censusTracts)

# %%
pol = bx['features']

# %%
utm.from_latlon(bx['features'][0]['geometry']['coordinates'][0][0][0][0],bx['features'][0]['geometry']['coordinates'][0][0][0][1])
# Out:
# (550313.6248663277, 1778431.4359987546, 37, 'C')

# %%
bx['features'][0]['geometry']['coordinates'][0][0][0]
# Out:
# [-74.07920577013245, 40.64343078374567]

# %%
bx['features'][0]['properties']
# Out:
# {'boro_code': '5',
#  'boro_ct2010': '5000900',
#  'boro_name': 'Staten Island',
#  'cdeligibil': 'I',
#  'ct2010': '000900',
#  'ctlabel': '9',
#  'ntacode': 'SI22',
#  'ntaname': 'West New Brighton-New Brighton-St. George',
#  'puma': '3903',
#  'shape_area': '2497009.69813',
#  'shape_leng': '7729.01679376'}

# %%
plt.figure(figsize=[12,12])
for x in range(len(censusTracts)):
	plt.plot(censusTracts[x][:, 0] , censusTracts[x][:, 1]  , '-',color='#888888')

plt.axes().set_aspect(1.25, 'datalim')
plt.xlim(xmin=-74.05, xmax=-73.75)
plt.ylim(ymin=40.55, ymax=40.89)
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import pandas as pd
df = pd.read_pickle('./Ballantyne_Metis/project_1/merged_MTA_final.pickle')

# %%
df.head()
# Out:
#          STATION       ENTRIES         EXITS        volume  \
# 0           1 AV  16640.285714  17975.576923  34615.862637
# 1         103 ST  24898.337912  15611.291209  40509.629121
# 2  103 ST-CORONA  16990.513736  10904.483516  27894.997253
# 3         104 ST   2476.923077    701.524725   3178.447802
# 4         110 ST   9581.337912   6975.239011  16556.576923
#
#                                geo  CensusTract    County    Borough  \
# 0  (40.7309749758, -73.9816808749)  36061003400  New York  Manhattan
# 1  (40.7994460003, -73.9683789996)  36061019100  New York  Manhattan
# 2  (40.7994460003, -73.9683789996)  36061019100  New York  Manhattan
# 3  (40.6817110011, -73.8376830006)  36081009400    Queens     Queens
# 4  (40.7950200001, -73.9442499969)  36061017200  New York  Manhattan
#
#    TotalPop   Men     ...      OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0      6476  3163     ...              8.3         6.0         30.0      4480
# ...

# %%
plt.figure(figsize=[12,12])
for x in range(len(censusTracts)):
	plt.plot(censusTracts[x][:, 0] , censusTracts[x][:, 1]  , '-',color='#888888')

plt.axes().set_aspect(1.25, 'datalim')
plt.xlim(xmin=-74.05, xmax=-73.75)
plt.ylim(ymin=40.55, ymax=40.89)

k = 0
px = df.geo[k][0]
py = df.geo[k][1]
plt.plot(py, px , 's',color='#FF0000')

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# Out:
# 40.730974975800663
